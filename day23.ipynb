# %%
data = "Ride101-Ramesh-Late Arrival-Bangalore, Ride102-Suresh-rude behavior-Hyderabad, Ride103-Mahesh-Late arrival-Bangalore"
print(data)
# Out:
# Ride101-Ramesh-Late Arrival-Bangalore, Ride102-Suresh-rude behavior-Hyderabad, Ride103-Mahesh-Late arrival-Bangalore

# %%
data = data.lower()
print(data)
# Out:
# ride101-ramesh-late arrival-bangalore, ride102-suresh-rude behavior-hyderabad, ride103-mahesh-late arrival-bangalore

# %%
Total_Complaints= data.count(",") + 1 
print(Total_Complaints)
# Out:
# 3

# %%
Late_Arrival= data.count("late arrival")
print(Late_Arrival)
# Out:
# 2

# %%
Bangalore_complaints = data.count("bangalore")
print(Bangalore_complaints)
# Out:
# 2

# %%
first_name = data.split(",") [0]
print(first_name)
print("ramesh")
# Out:
# ride101-ramesh-late arrival-bangalore
# ramesh

# %%
data = data.replace("rude behavior","rude_behavior")
data = data.replace("late arrival","lata_arrival")
print(data)
# Out:
# ride101-ramesh-lata_arrival-bangalore, ride102-suresh-rude_behavior-hyderabad, ride103-mahesh-lata_arrival-bangalore
